# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["PYTHONPATH"] = "/root/myhomedir/bucket/DIET_torch"
# !cd /root/myhomedir/bucket/DIET_torch && python3 train.py \
  --data data/nlu_sample.yml \
  --val-data data/nlu_test.yml
# Out:
# Loaded 25 training examples (22 validation examples)
# Vocabularies: 5 intents, 10 tags, sparse_dim=867
# Loading Qwen tokeniser from Qwen/Qwen2.5-0.5B-Instruct …
# Loading Qwen model from Qwen/Qwen2.5-0.5B-Instruct …
# 2026-04-07 08:59:01.661231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775552341.679426     384 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775552341.685213     384 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775552341.701947     384 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775552341.701976     384 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775552341.701979     384 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775552341.701983     384 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-07 08:59:01.706723: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Pre-computing Qwen embeddings for training set…
# Pre-computing Qwen embeddings for validation set…
# Trainable DIET parameters: 1,484,034
# Starting training – 100 epochs, device=cuda, entity_extractor=crf
# Traceback (most recent call last):
#   File "/root/myhomedir/bucket/DIET_torch/train.py", line 153, in <module>
#     main()
#   File "/root/myhomedir/bucket/DIET_torch/train.py", line 145, in main
#     trainer.train(
#   File "/root/myhomedir/bucket/DIET_torch/training/trainer.py", line 254, in train
#     for batch in train_loader:
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 701, in __next__
#     data = self._next_data()
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 757, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#   File "/root/myhomedir/bucket/DIET_torch/data/dataset.py", line 94, in collate_fn
#     torch.from_numpy(np.stack(pretrained_list))
#   File "/opt/conda/lib/python3.10/site-packages/numpy/_core/shape_base.py", line 448, in stack
#     raise ValueError('all input arrays must have the same shape')
# ValueError: all input arrays must have the same shape

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["PYTHONPATH"] = "/root/myhomedir/bucket/DIET_torch"
# !cd /root/myhomedir/bucket/DIET_torch && python3 train.py \
  --data data/nlu_sample.yml \
  --val-data data/nlu_test.yml
# Out:
# Loaded 25 training examples (22 validation examples)
# Vocabularies: 5 intents, 10 tags, sparse_dim=867
# Loading Qwen tokeniser from Qwen/Qwen2.5-0.5B-Instruct …
# Loading Qwen model from Qwen/Qwen2.5-0.5B-Instruct …
# 2026-04-07 09:00:46.361672: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775552446.378696     453 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775552446.384410     453 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775552446.400987     453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775552446.401013     453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775552446.401017     453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775552446.401021     453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-07 09:00:46.405965: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Pre-computing Qwen embeddings for training set…
# Pre-computing Qwen embeddings for validation set…
# Trainable DIET parameters: 1,484,034
# Starting training – 100 epochs, device=cuda, entity_extractor=crf
# Traceback (most recent call last):
#   File "/root/myhomedir/bucket/DIET_torch/train.py", line 153, in <module>
#     main()
#   File "/root/myhomedir/bucket/DIET_torch/train.py", line 145, in main
#     trainer.train(
#   File "/root/myhomedir/bucket/DIET_torch/training/trainer.py", line 255, in train
#     metrics = self._train_step(batch)
#   File "/root/myhomedir/bucket/DIET_torch/training/trainer.py", line 138, in _train_step
#     out = self.model(
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/root/myhomedir/bucket/DIET_torch/models/diet.py", line 145, in forward
#     fused = self._fuse_features(sparse, pretrained)   # (B, L, H)
#   File "/root/myhomedir/bucket/DIET_torch/models/diet.py", line 84, in _fuse_features
#     combined = torch.cat([sparse_proj, dense_proj], dim=-1)   # (B, L, H)
# RuntimeError: Sizes of tensors must match except in dimension 2. Expected size 10 but got size 17 for tensor number 1 in the list.

# %%
# !cd /root/myhomedir/bucket/DIET_torch && python3 train.py \
  --data data/nlu_sample.yml \
  --val-data data/nlu_test.yml
# Out:
# Loaded 25 training examples (22 validation examples)
# Vocabularies: 5 intents, 10 tags, sparse_dim=867
# Loading Qwen tokeniser from Qwen/Qwen2.5-0.5B-Instruct …
# Loading Qwen model from Qwen/Qwen2.5-0.5B-Instruct …
# 2026-04-07 09:10:25.603424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775553025.620184     638 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775553025.625583     638 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775553025.642197     638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553025.642228     638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553025.642232     638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553025.642236     638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-07 09:10:25.647100: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Pre-computing Qwen embeddings for training set…
# Pre-computing Qwen embeddings for validation set…
# Trainable DIET parameters: 1,484,034
# Starting training – 100 epochs, device=cuda, entity_extractor=crf
# Epoch   1/100 (0.3s) | train loss=20.3856 | entity_loss=11.2299 | intent_loss=8.7564 | mask_loss=0.7985 | intent_acc=0.2361
#           val   | intent_acc=0.1818 | entity_f1=0.1053
#           → New best checkpoint saved (score=0.1435)
# Epoch   2/100 (0.0s) | train loss=20.8398 | entity_loss=10.8761 | intent_loss=9.5808 | mask_loss=0.7658 | intent_acc=0.2361
#           val   | intent_acc=0.1818 | entity_f1=0.1000
# Epoch   3/100 (0.0s) | train loss=17.9203 | entity_loss=10.7267 | intent_loss=6.7981 | mask_loss=0.7910 | intent_acc=0.2361
#           val   | intent_acc=0.1818 | entity_f1=0.0952
# Epoch   4/100 (0.0s) | train loss=18.7829 | entity_loss=10.7363 | intent_loss=7.6538 | mask_loss=0.7856 | intent_acc=0.1806
#           val   | intent_acc=0.2727 | entity_f1=0.0465
#           → New best checkpoint saved (score=0.1596)
#   step     10 | loss=15.8869 | entity_loss=10.0414 | intent_loss=5.4670 | mask_loss=0.7570 | intent_acc=0.2674 | lr=5.00e-05
# Epoch   5/100 (0.0s) | train loss=15.8869 | entity_loss=10.0414 | intent_loss=5.4670 | mask_loss=0.7570 | intent_acc=0.2674
#           val   | intent_acc=0.1818 | entity_f1=0.0000
# Epoch   6/100 (0.0s) | train loss=14.2064 | entity_loss=9.3421 | intent_loss=4.5076 | mask_loss=0.7135 | intent_acc=0.3229
#           val   | intent_acc=0.2273 | entity_f1=0.0000
# Epoch   7/100 (0.0s) | train loss=12.3531 | entity_loss=8.1914 | intent_loss=3.8121 | mask_loss=0.6993 | intent_acc=0.3785
#           val   | intent_acc=0.2273 | entity_f1=0.0000
# Epoch   8/100 (0.0s) | train loss=11.0560 | entity_loss=6.8270 | intent_loss=3.8991 | mask_loss=0.6596 | intent_acc=0.4722
#           val   | intent_acc=0.5000 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.2500)
# Epoch   9/100 (0.0s) | train loss=8.2167 | entity_loss=5.9865 | intent_loss=1.9123 | mask_loss=0.6358 | intent_acc=0.6146
#           val   | intent_acc=0.5455 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.2727)
#   step     20 | loss=7.9679 | entity_loss=5.6469 | intent_loss=2.0190 | mask_loss=0.6039 | intent_acc=0.5035 | lr=1.00e-04
# Epoch  10/100 (0.0s) | train loss=7.9679 | entity_loss=5.6469 | intent_loss=2.0190 | mask_loss=0.6039 | intent_acc=0.5035
#           val   | intent_acc=0.4545 | entity_f1=0.0000
# Epoch  11/100 (0.0s) | train loss=6.8140 | entity_loss=5.5454 | intent_loss=0.9785 | mask_loss=0.5802 | intent_acc=0.7396
#           val   | intent_acc=0.5909 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.2955)
# Epoch  12/100 (0.0s) | train loss=8.0007 | entity_loss=6.0000 | intent_loss=1.7112 | mask_loss=0.5792 | intent_acc=0.7639
#           val   | intent_acc=0.6364 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.3182)
# Epoch  13/100 (0.0s) | train loss=6.9375 | entity_loss=5.1701 | intent_loss=1.5107 | mask_loss=0.5134 | intent_acc=0.6771
#           val   | intent_acc=0.6364 | entity_f1=0.0000
# Epoch  14/100 (0.0s) | train loss=5.9460 | entity_loss=4.7919 | intent_loss=0.9070 | mask_loss=0.4942 | intent_acc=0.6771
#           val   | intent_acc=0.7727 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.3864)
#   step     30 | loss=5.1222 | entity_loss=4.6170 | intent_loss=0.2715 | mask_loss=0.4672 | intent_acc=0.8819 | lr=1.50e-04
# Epoch  15/100 (0.0s) | train loss=5.1222 | entity_loss=4.6170 | intent_loss=0.2715 | mask_loss=0.4672 | intent_acc=0.8819
#           val   | intent_acc=0.9091 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.4545)
# Epoch  16/100 (0.0s) | train loss=5.9635 | entity_loss=4.7399 | intent_loss=0.9924 | mask_loss=0.4622 | intent_acc=0.7708
#           val   | intent_acc=0.8636 | entity_f1=0.0000
# Epoch  17/100 (0.0s) | train loss=5.0209 | entity_loss=4.6031 | intent_loss=0.1942 | mask_loss=0.4473 | intent_acc=0.9132
#           val   | intent_acc=0.7727 | entity_f1=0.0000
# Epoch  18/100 (0.0s) | train loss=5.1509 | entity_loss=3.8349 | intent_loss=1.0949 | mask_loss=0.4422 | intent_acc=0.7465
#           val   | intent_acc=0.7727 | entity_f1=0.0000
# Epoch  19/100 (0.0s) | train loss=4.3468 | entity_loss=3.8136 | intent_loss=0.3249 | mask_loss=0.4166 | intent_acc=0.9375
#           val   | intent_acc=0.5909 | entity_f1=0.0000
#   step     40 | loss=4.4889 | entity_loss=3.5677 | intent_loss=0.7216 | mask_loss=0.3994 | intent_acc=0.8333 | lr=2.00e-04
# Epoch  20/100 (0.0s) | train loss=4.4889 | entity_loss=3.5677 | intent_loss=0.7216 | mask_loss=0.3994 | intent_acc=0.8333
#           val   | intent_acc=0.6818 | entity_f1=0.0000
# Epoch  21/100 (0.1s) | train loss=4.9889 | entity_loss=3.2524 | intent_loss=1.5350 | mask_loss=0.4031 | intent_acc=0.8507
#           val   | intent_acc=0.7273 | entity_f1=0.0000
# Epoch  22/100 (0.0s) | train loss=3.0545 | entity_loss=2.7769 | intent_loss=0.0743 | mask_loss=0.4067 | intent_acc=0.9444
#           val   | intent_acc=0.7727 | entity_f1=0.0000
# Epoch  23/100 (0.0s) | train loss=2.4655 | entity_loss=2.2586 | intent_loss=0.0076 | mask_loss=0.3987 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.0000
# Epoch  24/100 (0.0s) | train loss=2.4110 | entity_loss=2.1924 | intent_loss=0.0106 | mask_loss=0.4159 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.3871
#           → New best checkpoint saved (score=0.6026)
#   step     50 | loss=3.2257 | entity_loss=2.0088 | intent_loss=1.0123 | mask_loss=0.4091 | intent_acc=0.8576 | lr=2.50e-04
# Epoch  25/100 (0.0s) | train loss=3.2257 | entity_loss=2.0088 | intent_loss=1.0123 | mask_loss=0.4091 | intent_acc=0.8576
#           val   | intent_acc=0.9091 | entity_f1=0.5556
#           → New best checkpoint saved (score=0.7323)
# Epoch  26/100 (0.0s) | train loss=1.6427 | entity_loss=1.4203 | intent_loss=0.0003 | mask_loss=0.4441 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.6111
#           → New best checkpoint saved (score=0.7601)
# Epoch  27/100 (0.0s) | train loss=1.1982 | entity_loss=0.9728 | intent_loss=0.0000 | mask_loss=0.4507 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.6111
# Epoch  28/100 (0.0s) | train loss=2.1194 | entity_loss=1.2153 | intent_loss=0.6763 | mask_loss=0.4556 | intent_acc=0.9444
#           val   | intent_acc=0.9545 | entity_f1=0.6111
#           → New best checkpoint saved (score=0.7828)
# Epoch  29/100 (0.0s) | train loss=0.9141 | entity_loss=0.6913 | intent_loss=0.0005 | mask_loss=0.4447 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.6667
#   step     60 | loss=0.7272 | entity_loss=0.5092 | intent_loss=0.0022 | mask_loss=0.4317 | intent_acc=1.0000 | lr=3.00e-04
# Epoch  30/100 (0.0s) | train loss=0.7272 | entity_loss=0.5092 | intent_loss=0.0022 | mask_loss=0.4317 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.6667
# Epoch  31/100 (0.0s) | train loss=1.9693 | entity_loss=1.6776 | intent_loss=0.0710 | mask_loss=0.4413 | intent_acc=0.9444
#           val   | intent_acc=0.7727 | entity_f1=0.7222
# Epoch  32/100 (0.0s) | train loss=1.1080 | entity_loss=0.6139 | intent_loss=0.2761 | mask_loss=0.4359 | intent_acc=0.9132
#           val   | intent_acc=0.7273 | entity_f1=0.7222
# Epoch  33/100 (0.0s) | train loss=1.2660 | entity_loss=0.8413 | intent_loss=0.1918 | mask_loss=0.4657 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.7368
#           → New best checkpoint saved (score=0.8230)
# Epoch  34/100 (0.0s) | train loss=1.0447 | entity_loss=0.8091 | intent_loss=0.0053 | mask_loss=0.4606 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7368
#   step     70 | loss=1.6017 | entity_loss=0.5970 | intent_loss=0.7884 | mask_loss=0.4326 | intent_acc=0.9688 | lr=3.50e-04
# Epoch  35/100 (0.0s) | train loss=1.6017 | entity_loss=0.5970 | intent_loss=0.7884 | mask_loss=0.4326 | intent_acc=0.9688
#           val   | intent_acc=0.8636 | entity_f1=0.6842
# Epoch  36/100 (0.0s) | train loss=1.1325 | entity_loss=0.4123 | intent_loss=0.5157 | mask_loss=0.4090 | intent_acc=0.8819
#           val   | intent_acc=0.8182 | entity_f1=0.5789
# Epoch  37/100 (0.0s) | train loss=0.7005 | entity_loss=0.4745 | intent_loss=0.0000 | mask_loss=0.4520 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6316
# Epoch  38/100 (0.0s) | train loss=2.3381 | entity_loss=0.6868 | intent_loss=1.4197 | mask_loss=0.4632 | intent_acc=0.8889
#           val   | intent_acc=0.9091 | entity_f1=0.6486
# Epoch  39/100 (0.0s) | train loss=0.7397 | entity_loss=0.5316 | intent_loss=0.0066 | mask_loss=0.4030 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.7027
#   step     80 | loss=0.4524 | entity_loss=0.1208 | intent_loss=0.1239 | mask_loss=0.4154 | intent_acc=0.9688 | lr=4.00e-04
# Epoch  40/100 (0.0s) | train loss=0.4524 | entity_loss=0.1208 | intent_loss=0.1239 | mask_loss=0.4154 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.6667
# Epoch  41/100 (0.0s) | train loss=0.5629 | entity_loss=0.3519 | intent_loss=0.0130 | mask_loss=0.3959 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6667
# Epoch  42/100 (0.0s) | train loss=0.4635 | entity_loss=0.2555 | intent_loss=0.0000 | mask_loss=0.4159 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7568
# Epoch  43/100 (0.0s) | train loss=1.6725 | entity_loss=1.4398 | intent_loss=0.0038 | mask_loss=0.4579 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7895
# Epoch  44/100 (0.0s) | train loss=2.3379 | entity_loss=0.5621 | intent_loss=1.5582 | mask_loss=0.4353 | intent_acc=0.8507
#           val   | intent_acc=0.8182 | entity_f1=0.7179
#   step     90 | loss=1.7184 | entity_loss=1.0648 | intent_loss=0.4205 | mask_loss=0.4662 | intent_acc=0.9688 | lr=4.50e-04
# Epoch  45/100 (0.0s) | train loss=1.7184 | entity_loss=1.0648 | intent_loss=0.4205 | mask_loss=0.4662 | intent_acc=0.9688
#           val   | intent_acc=0.8182 | entity_f1=0.6667
# Epoch  46/100 (0.0s) | train loss=1.1938 | entity_loss=0.7348 | intent_loss=0.2259 | mask_loss=0.4660 | intent_acc=0.9375
#           val   | intent_acc=0.8182 | entity_f1=0.6667
# Epoch  47/100 (0.0s) | train loss=0.9927 | entity_loss=0.7423 | intent_loss=0.0000 | mask_loss=0.5009 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7568
# Epoch  48/100 (0.0s) | train loss=2.1233 | entity_loss=0.5595 | intent_loss=1.3400 | mask_loss=0.4476 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.6842
# Epoch  49/100 (0.0s) | train loss=0.6247 | entity_loss=0.4034 | intent_loss=0.0009 | mask_loss=0.4407 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.6842
#   step    100 | loss=0.4933 | entity_loss=0.2797 | intent_loss=0.0103 | mask_loss=0.4066 | intent_acc=1.0000 | lr=5.00e-04
# Epoch  50/100 (0.0s) | train loss=0.4933 | entity_loss=0.2797 | intent_loss=0.0103 | mask_loss=0.4066 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6857
# Epoch  51/100 (0.0s) | train loss=1.3827 | entity_loss=1.1438 | intent_loss=0.0075 | mask_loss=0.4626 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6667
# Epoch  52/100 (0.0s) | train loss=1.2843 | entity_loss=0.7394 | intent_loss=0.3164 | mask_loss=0.4572 | intent_acc=0.9132
#           val   | intent_acc=0.8182 | entity_f1=0.6842
# Epoch  53/100 (0.0s) | train loss=0.3973 | entity_loss=0.1829 | intent_loss=0.0001 | mask_loss=0.4287 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6842
# Epoch  54/100 (0.0s) | train loss=0.7578 | entity_loss=0.5358 | intent_loss=0.0008 | mask_loss=0.4423 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.7027
#   step    110 | loss=0.4207 | entity_loss=0.2032 | intent_loss=0.0001 | mask_loss=0.4348 | intent_acc=1.0000 | lr=5.50e-04
# Epoch  55/100 (0.0s) | train loss=0.4207 | entity_loss=0.2032 | intent_loss=0.0001 | mask_loss=0.4348 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.6857
# Epoch  56/100 (0.0s) | train loss=1.1163 | entity_loss=0.3981 | intent_loss=0.4881 | mask_loss=0.4602 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.6667
# Epoch  57/100 (0.0s) | train loss=0.5484 | entity_loss=0.3326 | intent_loss=0.0005 | mask_loss=0.4306 | intent_acc=1.0000
#           val   | intent_acc=0.6818 | entity_f1=0.7568
# Epoch  58/100 (0.0s) | train loss=1.0073 | entity_loss=0.7265 | intent_loss=0.0608 | mask_loss=0.4402 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.7568
#           → New best checkpoint saved (score=0.8329)
# Epoch  59/100 (0.0s) | train loss=2.1633 | entity_loss=1.8845 | intent_loss=0.0427 | mask_loss=0.4723 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7568
#   step    120 | loss=1.4219 | entity_loss=0.4246 | intent_loss=0.7696 | mask_loss=0.4553 | intent_acc=0.9444 | lr=6.00e-04
# Epoch  60/100 (0.0s) | train loss=1.4219 | entity_loss=0.4246 | intent_loss=0.7696 | mask_loss=0.4553 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.6667
# Epoch  61/100 (0.1s) | train loss=0.7019 | entity_loss=0.4544 | intent_loss=0.0013 | mask_loss=0.4925 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.6667
# Epoch  62/100 (0.0s) | train loss=0.8669 | entity_loss=0.3438 | intent_loss=0.3084 | mask_loss=0.4295 | intent_acc=0.9688
#           val   | intent_acc=0.8636 | entity_f1=0.7027
# Epoch  63/100 (0.0s) | train loss=0.9450 | entity_loss=0.3716 | intent_loss=0.3296 | mask_loss=0.4876 | intent_acc=0.9688
#           val   | intent_acc=0.8182 | entity_f1=0.7368
# Epoch  64/100 (0.0s) | train loss=0.8220 | entity_loss=0.5243 | intent_loss=0.0420 | mask_loss=0.5115 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.7368
#   step    130 | loss=0.6147 | entity_loss=0.3889 | intent_loss=0.0012 | mask_loss=0.4492 | intent_acc=1.0000 | lr=6.50e-04
# Epoch  65/100 (0.0s) | train loss=0.6147 | entity_loss=0.3889 | intent_loss=0.0012 | mask_loss=0.4492 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.6842
# Epoch  66/100 (0.0s) | train loss=0.2595 | entity_loss=0.0616 | intent_loss=0.0000 | mask_loss=0.3958 | intent_acc=1.0000
#           val   | intent_acc=0.6818 | entity_f1=0.7368
# Epoch  67/100 (0.0s) | train loss=0.9126 | entity_loss=0.3440 | intent_loss=0.3340 | mask_loss=0.4691 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.7368
# Epoch  68/100 (0.0s) | train loss=0.9326 | entity_loss=0.7001 | intent_loss=0.0000 | mask_loss=0.4651 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.7179
# Epoch  69/100 (0.0s) | train loss=0.7896 | entity_loss=0.5761 | intent_loss=0.0001 | mask_loss=0.4269 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.7368
#   step    140 | loss=0.2816 | entity_loss=0.0812 | intent_loss=0.0000 | mask_loss=0.4008 | intent_acc=1.0000 | lr=7.00e-04
# Epoch  70/100 (0.0s) | train loss=0.2816 | entity_loss=0.0812 | intent_loss=0.0000 | mask_loss=0.4008 | intent_acc=1.0000
#           val   | intent_acc=0.9545 | entity_f1=0.7368
#           → New best checkpoint saved (score=0.8457)
# Epoch  71/100 (0.0s) | train loss=0.6958 | entity_loss=0.3799 | intent_loss=0.0944 | mask_loss=0.4431 | intent_acc=0.9444
#           val   | intent_acc=0.9545 | entity_f1=0.7027
# Epoch  72/100 (0.0s) | train loss=0.5501 | entity_loss=0.1917 | intent_loss=0.1382 | mask_loss=0.4404 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.7222
# Epoch  73/100 (0.0s) | train loss=3.9854 | entity_loss=0.8826 | intent_loss=2.8737 | mask_loss=0.4581 | intent_acc=0.9132
#           val   | intent_acc=0.9091 | entity_f1=0.7429
# Epoch  74/100 (0.0s) | train loss=0.6941 | entity_loss=0.4449 | intent_loss=0.0000 | mask_loss=0.4982 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.7568
#   step    150 | loss=0.9375 | entity_loss=0.2507 | intent_loss=0.4775 | mask_loss=0.4187 | intent_acc=0.9688 | lr=7.50e-04
# Epoch  75/100 (0.0s) | train loss=0.9375 | entity_loss=0.2507 | intent_loss=0.4775 | mask_loss=0.4187 | intent_acc=0.9688
#           val   | intent_acc=0.6818 | entity_f1=0.7027
# Epoch  76/100 (0.0s) | train loss=1.7939 | entity_loss=0.4778 | intent_loss=1.0945 | mask_loss=0.4433 | intent_acc=0.8264
#           val   | intent_acc=0.7727 | entity_f1=0.6667
# Epoch  77/100 (0.0s) | train loss=1.8586 | entity_loss=0.4612 | intent_loss=1.1849 | mask_loss=0.4252 | intent_acc=0.9132
#           val   | intent_acc=0.9091 | entity_f1=0.7778
# Epoch  78/100 (0.0s) | train loss=1.1284 | entity_loss=0.9180 | intent_loss=0.0014 | mask_loss=0.4180 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.7059
# Epoch  79/100 (0.0s) | train loss=1.0719 | entity_loss=0.6811 | intent_loss=0.1580 | mask_loss=0.4655 | intent_acc=0.8819
#           val   | intent_acc=0.8182 | entity_f1=0.6875
#   step    160 | loss=1.1325 | entity_loss=0.4634 | intent_loss=0.4297 | mask_loss=0.4787 | intent_acc=0.9688 | lr=8.00e-04
# Epoch  80/100 (0.0s) | train loss=1.1325 | entity_loss=0.4634 | intent_loss=0.4297 | mask_loss=0.4787 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.6857
# Epoch  81/100 (0.0s) | train loss=0.8108 | entity_loss=0.4698 | intent_loss=0.1136 | mask_loss=0.4550 | intent_acc=0.9688
#           val   | intent_acc=0.8182 | entity_f1=0.6842
# Epoch  82/100 (0.0s) | train loss=1.0701 | entity_loss=0.7289 | intent_loss=0.1032 | mask_loss=0.4759 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.6842
# Epoch  83/100 (0.0s) | train loss=1.4697 | entity_loss=0.7842 | intent_loss=0.4572 | mask_loss=0.4567 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.6667
# Epoch  84/100 (0.0s) | train loss=0.5318 | entity_loss=0.2868 | intent_loss=0.0001 | mask_loss=0.4899 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7027
#   step    170 | loss=0.8394 | entity_loss=0.3338 | intent_loss=0.2600 | mask_loss=0.4912 | intent_acc=0.9688 | lr=8.50e-04
# Epoch  85/100 (0.0s) | train loss=0.8394 | entity_loss=0.3338 | intent_loss=0.2600 | mask_loss=0.4912 | intent_acc=0.9688
#           val   | intent_acc=0.8636 | entity_f1=0.7027
# Epoch  86/100 (0.0s) | train loss=1.3761 | entity_loss=0.8806 | intent_loss=0.2508 | mask_loss=0.4892 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.7368
# Epoch  87/100 (0.0s) | train loss=0.3047 | entity_loss=0.0894 | intent_loss=0.0000 | mask_loss=0.4307 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7368
# Epoch  88/100 (0.0s) | train loss=1.1379 | entity_loss=0.9033 | intent_loss=0.0014 | mask_loss=0.4663 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.6842
# Epoch  89/100 (0.0s) | train loss=0.6531 | entity_loss=0.4182 | intent_loss=0.0016 | mask_loss=0.4666 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6842
#   step    180 | loss=0.7271 | entity_loss=0.5017 | intent_loss=0.0060 | mask_loss=0.4387 | intent_acc=1.0000 | lr=9.00e-04
# Epoch  90/100 (0.0s) | train loss=0.7271 | entity_loss=0.5017 | intent_loss=0.0060 | mask_loss=0.4387 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6842
# Epoch  91/100 (0.0s) | train loss=0.5561 | entity_loss=0.3301 | intent_loss=0.0003 | mask_loss=0.4512 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.6842
# Epoch  92/100 (0.0s) | train loss=1.4895 | entity_loss=0.3587 | intent_loss=0.9072 | mask_loss=0.4472 | intent_acc=0.9688
#           val   | intent_acc=0.7273 | entity_f1=0.8108
# Epoch  93/100 (0.0s) | train loss=0.7304 | entity_loss=0.4912 | intent_loss=0.0000 | mask_loss=0.4784 | intent_acc=1.0000
#           val   | intent_acc=0.6818 | entity_f1=0.8333
# Epoch  94/100 (0.0s) | train loss=1.1509 | entity_loss=0.8398 | intent_loss=0.0748 | mask_loss=0.4726 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.7027
#   step    190 | loss=1.1329 | entity_loss=0.2188 | intent_loss=0.7046 | mask_loss=0.4190 | intent_acc=0.9688 | lr=9.50e-04
# Epoch  95/100 (0.0s) | train loss=1.1329 | entity_loss=0.2188 | intent_loss=0.7046 | mask_loss=0.4190 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.7568
# Epoch  96/100 (0.0s) | train loss=1.5713 | entity_loss=1.3438 | intent_loss=0.0005 | mask_loss=0.4538 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.7778
# Epoch  97/100 (0.0s) | train loss=1.6856 | entity_loss=1.1018 | intent_loss=0.3226 | mask_loss=0.5225 | intent_acc=0.9688
#           val   | intent_acc=0.8182 | entity_f1=0.7778
# Epoch  98/100 (0.0s) | train loss=1.8298 | entity_loss=0.5645 | intent_loss=1.0424 | mask_loss=0.4457 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.7778
# Epoch  99/100 (0.0s) | train loss=0.5403 | entity_loss=0.3237 | intent_loss=0.0000 | mask_loss=0.4333 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7222
#   step    200 | loss=1.3399 | entity_loss=0.7449 | intent_loss=0.3798 | mask_loss=0.4304 | intent_acc=0.9375 | lr=1.00e-03
# Epoch 100/100 (0.0s) | train loss=1.3399 | entity_loss=0.7449 | intent_loss=0.3798 | mask_loss=0.4304 | intent_acc=0.9375
#           val   | intent_acc=0.8182 | entity_f1=0.7222
# Training complete.

# %%
# !cd /root/myhomedir/bucket/DIET_torch && python3 eval/run_eval.py \
  --checkpoint checkpoints/best.pt \
  --data data/nlu_test.yml \
  --output-dir eval/results \
  --prefix test \
  --device cuda
# Out:
# Loading Qwen tokeniser from Qwen/Qwen2.5-0.5B-Instruct …
# Loading Qwen model from Qwen/Qwen2.5-0.5B-Instruct …
# 2026-04-07 09:12:48.312237: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775553168.330400     685 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775553168.335592     685 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775553168.352455     685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553168.352487     685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553168.352490     685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553168.352494     685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-07 09:12:48.357674: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /root/myhomedir/bucket/DIET_torch/eval/run_eval.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(args.checkpoint, map_location=device)
# Traceback (most recent call last):
#   File "/root/myhomedir/bucket/DIET_torch/eval/run_eval.py", line 62, in <module>
#     main()
#   File "/root/myhomedir/bucket/DIET_torch/eval/run_eval.py", line 48, in main
#     model.load_state_dict(ckpt["model_state"])
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 2584, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for DIETModel:
# 	Missing key(s) in state_dict: "qwen_encoder.model.model.embed_tokens.weight", "qwen_encoder.model.model.layers.0.self_attn.q_proj.weight", "qwen_encoder.model.model.layers.0.self_attn.q_proj.bias", "qwen_encoder.model.model.layers.0.self_attn.k_proj.weight", "qwen_encoder.model.model.layers.0.self_attn.k_proj.bias", "qwen_encoder.model.model.layers.0.self_attn.v_proj.weight", "qwen_encoder.model.model.layers.0.self_attn.v_proj.bias", "qwen_encoder.model.model.layers.0.self_attn.o_proj.weight", "qwen_encoder.model.model.layers.0.mlp.gate_proj.weight", "qwen_encoder.model.model.layers.0.mlp.up_proj.weight", "qwen_encoder.model.model.layers.0.mlp.down_proj.weight", "qwen_encoder.model.model.layers.0.input_layernorm.weight", "qwen_encoder.model.model.layers.0.post_attention_layernorm.weight", "qwen_encoder.model.model.layers.1.self_attn.q_proj.weight", "qwen_encoder.model.model.layers.1.self_attn.q_proj.bias", "qwen_encoder.model.model.layers.1.self_attn.k_proj.weight", "qwen_encoder.model.model.layers.1.self_attn.k_proj.bias", "qwen_encoder.model.model.layers.1.self_attn.v_proj.weight", "qwen_encoder.model.model.layers.1.self_attn.v_proj.bias", "qwen_encoder.model.model.layers.1.self_attn.o_proj.weight", "qwen_encoder.model.model.layers.1.mlp.gate_proj.weight", "qwen_encoder.model.model.layers.1.mlp.up_proj.weight", "qwen_encoder.model.model.layers.1.mlp.down_proj.weight", "qwen_encoder.model.model.layers.1.input_layernorm.weight", "qwen_encoder.model.model.layers.1.post_attention_layernorm.weight", "qwen_encoder.model.model.layers.2.self_attn.q_proj.weight", "qwen_encoder.model.model.layers.2.self_attn.q_proj.bias", "qwen_encoder.model.model.layers.2.self_attn.k_proj.weight", "qwen_encoder.model.model.layers.2.self_attn.k_proj.bias", "qwen_encoder.model.model.layers.2.self_attn.v_proj.weight", "qwen_encoder.model.model.layers.2.self_attn.v_proj.bias", "qwen_encoder.model.model.layers.2.self_attn.o_proj.weight", "qwen_encoder.model.model.layers.2.mlp.gate_proj.weight", "qwen_encoder.model.model.layers.2.mlp.up_proj.weight", "qwen_encoder.model.model.layers.2.mlp.down_proj.weight", "qwen_encoder.model.model.layers.2.input_layernorm.weight", "qwen_encoder.model.model.layers.2.post_attention_layernorm.weight", "qwen_encoder.model.model.layers.3.self_attn.q_proj.weight", "qwen_encoder.model.model.layers.3.self_attn.q_proj.bias", "qwen_encoder.model.model.layers.3.self_attn.k_proj.weight", "qwen_encoder.model.model.layers.3.self_attn.k_proj.bias", "qwen_encoder.model.model.layers.3.self_attn.v_proj.weight", "qwen_encoder.model.model.layers.3.self_attn.v_proj.bias", "qwen_encoder.model.model.layers.3.self_attn.o_proj.weight", "qwen_encoder.model.model.layers.3.mlp.gate_proj.weight", "qwen_encoder.model.model.layers.3.mlp.up_proj.weight", "qwen_encoder.model.model.layers.3.mlp.down_proj.weight", "qwen_encoder.model.model.layers.3.input_layernorm.weight", "qwen_encoder.model.model.layers.3.post_attention_layernorm.weight", "qwen_encoder.model.model.layers.4.self_attn.q_proj.weight", "qwen_encoder.model.model.layers.4.self_attn.q_proj.bias", "qwen_encoder.model.model.layers.4.self_attn.k_proj.weight", "qwen_encoder.model.model.layers.4.self_attn.k_proj.bias", "qwen_encoder.model.model.layers.4.self_attn.v_proj.weight", "qwen_encoder.model.model.layers.4.self_attn.v_proj.bias", "qwen_encoder.model.model.layers.4.self_attn.o_proj.weight", "qwen_encoder.model.model.layers.4.mlp.gate_proj.weight", "qwen_encoder.model.model.layers.4.mlp.up_proj.weight", "qwen_encoder.model.model.layers.4.mlp.down_proj.weight", "qwen_encoder.model.model.layers.4.input_layernorm.weight", "qwen_encoder.model.model.layers.4.post_attention_layernorm.weight", "qwen_encoder.model.model.layers.5.self_attn.q_proj.weight", "qwen_encoder.model.model.layers.5.self_attn.q_proj.bias", "qwen_encoder.model.model.layers.5.self_attn.k_proj.weight", "qwen_encoder.model.model.layers.5.self_attn.k_proj.bias", "qwen_encoder.model.model.layers.5.self_attn.v_proj.weight", "qwen_enco ...

# %%
# !cd /root/myhomedir/bucket/DIET_torch && python3 eval/run_eval.py \
  --checkpoint checkpoints/best.pt \
  --data data/nlu_test.yml \
  --output-dir eval/results \
  --prefix test \
  --device cuda
# Out:
# Loading Qwen tokeniser from Qwen/Qwen2.5-0.5B-Instruct …
# Loading Qwen model from Qwen/Qwen2.5-0.5B-Instruct …
# 2026-04-07 09:56:00.460000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775555760.477454    1320 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775555760.482648    1320 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775555760.499518    1320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775555760.499543    1320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775555760.499547    1320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775555760.499550    1320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-07 09:56:00.504256: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded 22 test examples
#
# === INTENT CLASSIFICATION ===
#   micro       P=0.955  R=0.955  F1=0.955
#   macro       P=0.960  R=0.960  F1=0.956
#   weighted    P=0.964  R=0.955  F1=0.955
#
#   Per intent:
#     book_flight                P=1.000  R=1.000  F1=1.000  sup=4.0
#     check_weather              P=0.800  R=1.000  F1=0.889  sup=4.0
#     goodbye                    P=1.000  R=1.000  F1=1.000  sup=5.0
#     greet                      P=1.000  R=0.800  F1=0.889  sup=5.0  → confuses with 'check_weather' (1x)
#     search_restaurant          P=1.000  R=1.000  F1=1.000  sup=4.0
#
# === ENTITY EXTRACTION ===
#   micro       P=0.667  R=0.700  F1=0.683
#   macro       P=0.743  R=0.700  F1=0.701
#   weighted    P=0.743  R=0.700  F1=0.701
#
#   Per entity:
#     city                            P=1.000  R=1.000  F1=1.000  tp=4 fp=0 fn=0
#     city:departure                  P=0.800  R=1.000  F1=0.889  tp=4 fp=1 fn=0
#     city:destination                P=0.750  R=0.750  F1=0.750  tp=3 fp=1 fn=1
#     cuisine                         P=1.000  R=0.500  F1=0.667  tp=2 fp=0 fn=2
#     location                        P=0.167  R=0.250  F1=0.200  tp=1 fp=5 fn=3
#
#   Intent errors: 1 / 22
#   Entity errors: 5 / 22
#   Wrote eval/results/test_report.json
#   Wrote eval/results/test_intent_errors.json
#   Wrote eval/results/test_entity_errors.json

# %%
# !cd /root/myhomedir/bucket/DIET_torch && python3 train.py \
  --data data/nlu_sample.yml \
  --val-data data/nlu_test.yml
# Out:
# Loaded 25 training examples (22 validation examples)
# Vocabularies: 5 intents, 10 tags, sparse_dim=867
# Loading Qwen tokeniser from Qwen/Qwen2.5-0.5B-Instruct …
# Loading Qwen model from Qwen/Qwen2.5-0.5B-Instruct …
# 2026-04-07 11:35:22.081812: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775561722.098984     205 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775561722.104147     205 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775561722.121045     205 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775561722.121073     205 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775561722.121077     205 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775561722.121080     205 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-07 11:35:22.125986: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# trainable params: 1,081,344 || all params: 495,114,112 || trainable%: 0.2184
# Trainable DIET parameters: 2,565,378
# Starting training – 100 epochs, device=cuda, entity_extractor=crf
# Epoch   1/100 (1.6s) | train loss=23.9486 | entity_loss=12.6277 | intent_loss=10.9055 | mask_loss=0.8307 | intent_acc=0.1250
#           val   | intent_acc=0.1818 | entity_f1=0.0476
#           → New best checkpoint saved (score=0.1147)
# Epoch   2/100 (0.7s) | train loss=22.8944 | entity_loss=13.7369 | intent_loss=8.7307 | mask_loss=0.8536 | intent_acc=0.1493
#           val   | intent_acc=0.1818 | entity_f1=0.0476
# Epoch   3/100 (0.7s) | train loss=17.6517 | entity_loss=12.7505 | intent_loss=4.4748 | mask_loss=0.8528 | intent_acc=0.3160
#           val   | intent_acc=0.1818 | entity_f1=0.0000
# Epoch   4/100 (0.7s) | train loss=17.6085 | entity_loss=13.0897 | intent_loss=4.1191 | mask_loss=0.7995 | intent_acc=0.2917
#           val   | intent_acc=0.2727 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.1364)
#   step     10 | loss=18.0612 | entity_loss=11.8983 | intent_loss=5.7653 | mask_loss=0.7953 | intent_acc=0.2118 | lr=5.00e-05
# Epoch   5/100 (0.8s) | train loss=18.0612 | entity_loss=11.8983 | intent_loss=5.7653 | mask_loss=0.7953 | intent_acc=0.2118
#           val   | intent_acc=0.2727 | entity_f1=0.0426
#           → New best checkpoint saved (score=0.1576)
# Epoch   6/100 (0.8s) | train loss=16.2258 | entity_loss=10.8491 | intent_loss=4.9904 | mask_loss=0.7726 | intent_acc=0.3299
#           val   | intent_acc=0.2273 | entity_f1=0.0345
# Epoch   7/100 (0.7s) | train loss=15.2212 | entity_loss=8.9886 | intent_loss=5.8533 | mask_loss=0.7587 | intent_acc=0.2118
#           val   | intent_acc=0.3636 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.1818)
# Epoch   8/100 (0.7s) | train loss=12.6844 | entity_loss=7.5919 | intent_loss=4.7388 | mask_loss=0.7073 | intent_acc=0.3160
#           val   | intent_acc=0.4091 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.2045)
# Epoch   9/100 (0.7s) | train loss=11.4434 | entity_loss=6.6442 | intent_loss=4.4554 | mask_loss=0.6875 | intent_acc=0.2674
#           val   | intent_acc=0.4545 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.2273)
#   step     20 | loss=9.2321 | entity_loss=5.5410 | intent_loss=3.3828 | mask_loss=0.6165 | intent_acc=0.2917 | lr=1.00e-04
# Epoch  10/100 (0.8s) | train loss=9.2321 | entity_loss=5.5410 | intent_loss=3.3828 | mask_loss=0.6165 | intent_acc=0.2917
#           val   | intent_acc=0.5455 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.2727)
# Epoch  11/100 (0.7s) | train loss=7.4275 | entity_loss=5.9475 | intent_loss=1.1672 | mask_loss=0.6256 | intent_acc=0.7639
#           val   | intent_acc=0.5909 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.2955)
# Epoch  12/100 (0.8s) | train loss=7.5673 | entity_loss=5.4597 | intent_loss=1.8088 | mask_loss=0.5977 | intent_acc=0.5590
#           val   | intent_acc=0.6818 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.3409)
# Epoch  13/100 (0.8s) | train loss=6.7443 | entity_loss=5.6103 | intent_loss=0.8528 | mask_loss=0.5625 | intent_acc=0.7639
#           val   | intent_acc=0.4545 | entity_f1=0.0000
# Epoch  14/100 (0.7s) | train loss=6.8176 | entity_loss=5.3093 | intent_loss=1.2472 | mask_loss=0.5223 | intent_acc=0.6458
#           val   | intent_acc=0.6818 | entity_f1=0.0000
#   step     30 | loss=7.1243 | entity_loss=5.0524 | intent_loss=1.8204 | mask_loss=0.5029 | intent_acc=0.6771 | lr=1.50e-04
# Epoch  15/100 (0.7s) | train loss=7.1243 | entity_loss=5.0524 | intent_loss=1.8204 | mask_loss=0.5029 | intent_acc=0.6771
#           val   | intent_acc=0.6818 | entity_f1=0.0000
# Epoch  16/100 (0.7s) | train loss=5.8062 | entity_loss=4.3702 | intent_loss=1.2004 | mask_loss=0.4714 | intent_acc=0.7639
#           val   | intent_acc=0.6818 | entity_f1=0.0000
# Epoch  17/100 (0.7s) | train loss=4.9096 | entity_loss=4.0543 | intent_loss=0.6307 | mask_loss=0.4492 | intent_acc=0.7639
#           val   | intent_acc=0.7273 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.3636)
# Epoch  18/100 (0.7s) | train loss=4.8531 | entity_loss=3.8771 | intent_loss=0.7566 | mask_loss=0.4387 | intent_acc=0.8194
#           val   | intent_acc=0.7727 | entity_f1=0.0000
#           → New best checkpoint saved (score=0.3864)
# Epoch  19/100 (0.8s) | train loss=4.9594 | entity_loss=3.9596 | intent_loss=0.7862 | mask_loss=0.4272 | intent_acc=0.7951
#           val   | intent_acc=0.8182 | entity_f1=0.0952
#           → New best checkpoint saved (score=0.4567)
#   step     40 | loss=4.6641 | entity_loss=3.3687 | intent_loss=1.0801 | mask_loss=0.4305 | intent_acc=0.7396 | lr=2.00e-04
# Epoch  20/100 (0.8s) | train loss=4.6641 | entity_loss=3.3687 | intent_loss=1.0801 | mask_loss=0.4305 | intent_acc=0.7396
#           val   | intent_acc=0.7727 | entity_f1=0.0870
# Epoch  21/100 (0.7s) | train loss=4.6064 | entity_loss=3.7523 | intent_loss=0.6428 | mask_loss=0.4226 | intent_acc=0.8750
#           val   | intent_acc=0.6818 | entity_f1=0.1739
# Epoch  22/100 (0.7s) | train loss=4.2619 | entity_loss=2.8010 | intent_loss=1.2432 | mask_loss=0.4352 | intent_acc=0.9132
#           val   | intent_acc=0.7273 | entity_f1=0.1739
# Epoch  23/100 (0.7s) | train loss=3.8766 | entity_loss=3.0958 | intent_loss=0.5595 | mask_loss=0.4428 | intent_acc=0.8819
#           val   | intent_acc=0.7727 | entity_f1=0.2500
#           → New best checkpoint saved (score=0.5114)
# Epoch  24/100 (0.8s) | train loss=2.5337 | entity_loss=2.1343 | intent_loss=0.1907 | mask_loss=0.4174 | intent_acc=0.9375
#           val   | intent_acc=0.8182 | entity_f1=0.2500
#           → New best checkpoint saved (score=0.5341)
#   step     50 | loss=2.4647 | entity_loss=2.2442 | intent_loss=0.0112 | mask_loss=0.4187 | intent_acc=1.0000 | lr=2.50e-04
# Epoch  25/100 (0.8s) | train loss=2.4647 | entity_loss=2.2442 | intent_loss=0.0112 | mask_loss=0.4187 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.2308
# Epoch  26/100 (0.7s) | train loss=1.9479 | entity_loss=1.5603 | intent_loss=0.1769 | mask_loss=0.4215 | intent_acc=0.9375
#           val   | intent_acc=0.8636 | entity_f1=0.2963
#           → New best checkpoint saved (score=0.5800)
# Epoch  27/100 (0.8s) | train loss=2.1825 | entity_loss=1.6113 | intent_loss=0.3514 | mask_loss=0.4398 | intent_acc=0.9062
#           val   | intent_acc=0.8182 | entity_f1=0.4516
#           → New best checkpoint saved (score=0.6349)
# Epoch  28/100 (0.8s) | train loss=2.2628 | entity_loss=1.3136 | intent_loss=0.7365 | mask_loss=0.4254 | intent_acc=0.7951
#           val   | intent_acc=0.8182 | entity_f1=0.5882
#           → New best checkpoint saved (score=0.7032)
# Epoch  29/100 (0.8s) | train loss=1.1476 | entity_loss=0.9216 | intent_loss=0.0012 | mask_loss=0.4496 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.5714
#           → New best checkpoint saved (score=0.7403)
#   step     60 | loss=0.8924 | entity_loss=0.6703 | intent_loss=0.0009 | mask_loss=0.4423 | intent_acc=1.0000 | lr=3.00e-04
# Epoch  30/100 (0.8s) | train loss=0.8924 | entity_loss=0.6703 | intent_loss=0.0009 | mask_loss=0.4423 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.5882
# Epoch  31/100 (0.8s) | train loss=1.6881 | entity_loss=0.7819 | intent_loss=0.6854 | mask_loss=0.4416 | intent_acc=0.9132
#           val   | intent_acc=0.8636 | entity_f1=0.5455
# Epoch  32/100 (0.7s) | train loss=1.4220 | entity_loss=1.1963 | intent_loss=0.0000 | mask_loss=0.4514 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.6286
#           → New best checkpoint saved (score=0.7688)
# Epoch  33/100 (0.7s) | train loss=0.7176 | entity_loss=0.4474 | intent_loss=0.0601 | mask_loss=0.4201 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.6667
#           → New best checkpoint saved (score=0.7879)
# Epoch  34/100 (0.8s) | train loss=0.9230 | entity_loss=0.6817 | intent_loss=0.0056 | mask_loss=0.4715 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.7222
#           → New best checkpoint saved (score=0.8157)
#   step     70 | loss=0.8575 | entity_loss=0.5909 | intent_loss=0.0438 | mask_loss=0.4456 | intent_acc=0.9444 | lr=3.50e-04
# Epoch  35/100 (0.8s) | train loss=0.8575 | entity_loss=0.5909 | intent_loss=0.0438 | mask_loss=0.4456 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.7222
# Epoch  36/100 (0.7s) | train loss=1.7788 | entity_loss=0.2966 | intent_loss=1.2657 | mask_loss=0.4331 | intent_acc=0.9375
#           val   | intent_acc=0.7273 | entity_f1=0.7222
# Epoch  37/100 (0.7s) | train loss=0.8262 | entity_loss=0.5584 | intent_loss=0.0191 | mask_loss=0.4975 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.7222
# Epoch  38/100 (0.7s) | train loss=1.1469 | entity_loss=0.4139 | intent_loss=0.5122 | mask_loss=0.4417 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.6667
# Epoch  39/100 (0.7s) | train loss=1.6282 | entity_loss=0.9118 | intent_loss=0.4835 | mask_loss=0.4658 | intent_acc=0.8819
#           val   | intent_acc=0.8182 | entity_f1=0.7027
#   step     80 | loss=0.8252 | entity_loss=0.2951 | intent_loss=0.3089 | mask_loss=0.4423 | intent_acc=0.9688 | lr=4.00e-04
# Epoch  40/100 (0.7s) | train loss=0.8252 | entity_loss=0.2951 | intent_loss=0.3089 | mask_loss=0.4423 | intent_acc=0.9688
#           val   | intent_acc=0.8636 | entity_f1=0.6842
# Epoch  41/100 (0.7s) | train loss=1.0949 | entity_loss=0.8606 | intent_loss=0.0000 | mask_loss=0.4686 | intent_acc=1.0000
#           val   | intent_acc=0.6818 | entity_f1=0.7692
# Epoch  42/100 (0.7s) | train loss=1.7550 | entity_loss=0.8696 | intent_loss=0.6662 | mask_loss=0.4386 | intent_acc=0.9688
#           val   | intent_acc=0.5909 | entity_f1=0.7692
# Epoch  43/100 (0.7s) | train loss=1.5724 | entity_loss=0.9965 | intent_loss=0.3439 | mask_loss=0.4641 | intent_acc=0.8889
#           val   | intent_acc=0.7273 | entity_f1=0.7179
# Epoch  44/100 (0.7s) | train loss=1.6262 | entity_loss=1.2610 | intent_loss=0.1255 | mask_loss=0.4794 | intent_acc=0.9375
#           val   | intent_acc=0.8636 | entity_f1=0.8205
#           → New best checkpoint saved (score=0.8421)
#   step     90 | loss=0.8380 | entity_loss=0.6132 | intent_loss=0.0000 | mask_loss=0.4496 | intent_acc=1.0000 | lr=4.50e-04
# Epoch  45/100 (0.8s) | train loss=0.8380 | entity_loss=0.6132 | intent_loss=0.0000 | mask_loss=0.4496 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7568
# Epoch  46/100 (0.7s) | train loss=1.2688 | entity_loss=0.4587 | intent_loss=0.5891 | mask_loss=0.4420 | intent_acc=0.8819
#           val   | intent_acc=0.7727 | entity_f1=0.7222
# Epoch  47/100 (0.7s) | train loss=0.7733 | entity_loss=0.4041 | intent_loss=0.1462 | mask_loss=0.4460 | intent_acc=0.9375
#           val   | intent_acc=0.8636 | entity_f1=0.6667
# Epoch  48/100 (0.7s) | train loss=0.5330 | entity_loss=0.3047 | intent_loss=0.0000 | mask_loss=0.4566 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.6111
# Epoch  49/100 (0.7s) | train loss=1.0701 | entity_loss=0.8376 | intent_loss=0.0000 | mask_loss=0.4650 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6286
#   step    100 | loss=0.8029 | entity_loss=0.5799 | intent_loss=0.0000 | mask_loss=0.4459 | intent_acc=1.0000 | lr=5.00e-04
# Epoch  50/100 (0.7s) | train loss=0.8029 | entity_loss=0.5799 | intent_loss=0.0000 | mask_loss=0.4459 | intent_acc=1.0000
#           val   | intent_acc=0.6818 | entity_f1=0.4737
# Epoch  51/100 (0.8s) | train loss=1.2237 | entity_loss=0.8559 | intent_loss=0.1537 | mask_loss=0.4280 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.5405
# Epoch  52/100 (0.7s) | train loss=1.4818 | entity_loss=0.3990 | intent_loss=0.8652 | mask_loss=0.4353 | intent_acc=0.9444
#           val   | intent_acc=0.8182 | entity_f1=0.5405
# Epoch  53/100 (0.7s) | train loss=0.9551 | entity_loss=0.7197 | intent_loss=0.0179 | mask_loss=0.4349 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7027
# Epoch  54/100 (0.7s) | train loss=0.9139 | entity_loss=0.6798 | intent_loss=0.0074 | mask_loss=0.4534 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.8421
#           → New best checkpoint saved (score=0.8756)
#   step    110 | loss=1.5078 | entity_loss=0.8001 | intent_loss=0.4865 | mask_loss=0.4425 | intent_acc=0.9444 | lr=5.50e-04
# Epoch  55/100 (0.8s) | train loss=1.5078 | entity_loss=0.8001 | intent_loss=0.4865 | mask_loss=0.4425 | intent_acc=0.9444
#           val   | intent_acc=0.9091 | entity_f1=0.8205
# Epoch  56/100 (0.7s) | train loss=0.8293 | entity_loss=0.2059 | intent_loss=0.4202 | mask_loss=0.4066 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.8718
#           → New best checkpoint saved (score=0.8904)
# Epoch  57/100 (0.7s) | train loss=0.7423 | entity_loss=0.5002 | intent_loss=0.0178 | mask_loss=0.4487 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.8718
# Epoch  58/100 (0.7s) | train loss=0.6298 | entity_loss=0.2983 | intent_loss=0.1130 | mask_loss=0.4369 | intent_acc=0.9688
#           val   | intent_acc=0.8182 | entity_f1=0.7027
# Epoch  59/100 (0.7s) | train loss=1.1130 | entity_loss=0.8137 | intent_loss=0.0523 | mask_loss=0.4940 | intent_acc=0.9444
#           val   | intent_acc=0.8636 | entity_f1=0.7027
#   step    120 | loss=0.9619 | entity_loss=0.3036 | intent_loss=0.4437 | mask_loss=0.4291 | intent_acc=0.9444 | lr=6.00e-04
# Epoch  60/100 (0.7s) | train loss=0.9619 | entity_loss=0.3036 | intent_loss=0.4437 | mask_loss=0.4291 | intent_acc=0.9444
#           val   | intent_acc=0.8636 | entity_f1=0.6842
# Epoch  61/100 (0.8s) | train loss=0.8890 | entity_loss=0.1687 | intent_loss=0.4978 | mask_loss=0.4449 | intent_acc=0.9132
#           val   | intent_acc=0.8182 | entity_f1=0.6842
# Epoch  62/100 (0.7s) | train loss=1.2711 | entity_loss=1.0329 | intent_loss=0.0007 | mask_loss=0.4750 | intent_acc=1.0000
#           val   | intent_acc=0.7273 | entity_f1=0.6316
# Epoch  63/100 (0.7s) | train loss=1.3577 | entity_loss=0.9279 | intent_loss=0.2116 | mask_loss=0.4364 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.5789
# Epoch  64/100 (0.7s) | train loss=0.7986 | entity_loss=0.5204 | intent_loss=0.0487 | mask_loss=0.4589 | intent_acc=0.9688
#           val   | intent_acc=0.7273 | entity_f1=0.6842
#   step    130 | loss=0.4577 | entity_loss=0.2326 | intent_loss=0.0111 | mask_loss=0.4281 | intent_acc=1.0000 | lr=6.50e-04
# Epoch  65/100 (0.7s) | train loss=0.4577 | entity_loss=0.2326 | intent_loss=0.0111 | mask_loss=0.4281 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.8421
# Epoch  66/100 (0.7s) | train loss=0.9270 | entity_loss=0.6988 | intent_loss=0.0000 | mask_loss=0.4563 | intent_acc=1.0000
#           val   | intent_acc=1.0000 | entity_f1=0.8108
#           → New best checkpoint saved (score=0.9054)
# Epoch  67/100 (0.8s) | train loss=0.7085 | entity_loss=0.3585 | intent_loss=0.1212 | mask_loss=0.4575 | intent_acc=0.9688
#           val   | intent_acc=0.9091 | entity_f1=0.8333
# Epoch  68/100 (0.7s) | train loss=1.4863 | entity_loss=0.6540 | intent_loss=0.5962 | mask_loss=0.4723 | intent_acc=0.9688
#           val   | intent_acc=0.7727 | entity_f1=0.8000
# Epoch  69/100 (0.7s) | train loss=0.6977 | entity_loss=0.4652 | intent_loss=0.0026 | mask_loss=0.4597 | intent_acc=1.0000
#           val   | intent_acc=0.7273 | entity_f1=0.8571
#   step    140 | loss=1.4222 | entity_loss=0.7525 | intent_loss=0.4301 | mask_loss=0.4792 | intent_acc=0.9444 | lr=7.00e-04
# Epoch  70/100 (0.7s) | train loss=1.4222 | entity_loss=0.7525 | intent_loss=0.4301 | mask_loss=0.4792 | intent_acc=0.9444
#           val   | intent_acc=0.7727 | entity_f1=0.8649
# Epoch  71/100 (0.8s) | train loss=1.8104 | entity_loss=0.4550 | intent_loss=1.1262 | mask_loss=0.4584 | intent_acc=0.9132
#           val   | intent_acc=0.8636 | entity_f1=0.8108
# Epoch  72/100 (0.7s) | train loss=0.8174 | entity_loss=0.5888 | intent_loss=0.0002 | mask_loss=0.4570 | intent_acc=1.0000
#           val   | intent_acc=0.9545 | entity_f1=0.7895
# Epoch  73/100 (0.7s) | train loss=1.0515 | entity_loss=0.4773 | intent_loss=0.3527 | mask_loss=0.4431 | intent_acc=0.9444
#           val   | intent_acc=0.8636 | entity_f1=0.6842
# Epoch  74/100 (0.7s) | train loss=1.0177 | entity_loss=0.6249 | intent_loss=0.1555 | mask_loss=0.4748 | intent_acc=0.9688
#           val   | intent_acc=0.8636 | entity_f1=0.6842
#   step    150 | loss=0.6845 | entity_loss=0.4464 | intent_loss=0.0000 | mask_loss=0.4762 | intent_acc=1.0000 | lr=7.50e-04
# Epoch  75/100 (0.7s) | train loss=0.6845 | entity_loss=0.4464 | intent_loss=0.0000 | mask_loss=0.4762 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.6842
# Epoch  76/100 (0.7s) | train loss=0.8010 | entity_loss=0.5604 | intent_loss=0.0139 | mask_loss=0.4534 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.5556
# Epoch  77/100 (0.7s) | train loss=0.6560 | entity_loss=0.3923 | intent_loss=0.0281 | mask_loss=0.4710 | intent_acc=0.9688
#           val   | intent_acc=0.8182 | entity_f1=0.5556
# Epoch  78/100 (0.7s) | train loss=1.3237 | entity_loss=1.0640 | intent_loss=0.0000 | mask_loss=0.5194 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.6111
# Epoch  79/100 (0.7s) | train loss=0.8433 | entity_loss=0.6159 | intent_loss=0.0000 | mask_loss=0.4548 | intent_acc=1.0000
#           val   | intent_acc=0.7273 | entity_f1=0.6486
#   step    160 | loss=0.4122 | entity_loss=0.2010 | intent_loss=0.0002 | mask_loss=0.4222 | intent_acc=1.0000 | lr=8.00e-04
# Epoch  80/100 (0.7s) | train loss=0.4122 | entity_loss=0.2010 | intent_loss=0.0002 | mask_loss=0.4222 | intent_acc=1.0000
#           val   | intent_acc=0.6364 | entity_f1=0.6286
# Epoch  81/100 (0.8s) | train loss=0.9993 | entity_loss=0.7728 | intent_loss=0.0012 | mask_loss=0.4506 | intent_acc=1.0000
#           val   | intent_acc=0.5909 | entity_f1=0.6111
# Epoch  82/100 (0.7s) | train loss=1.2352 | entity_loss=0.6041 | intent_loss=0.4135 | mask_loss=0.4352 | intent_acc=0.9688
#           val   | intent_acc=0.5909 | entity_f1=0.6667
# Epoch  83/100 (0.7s) | train loss=0.4327 | entity_loss=0.2185 | intent_loss=0.0023 | mask_loss=0.4238 | intent_acc=1.0000
#           val   | intent_acc=0.6364 | entity_f1=0.7895
# Epoch  84/100 (0.7s) | train loss=0.8816 | entity_loss=0.6273 | intent_loss=0.0289 | mask_loss=0.4507 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.9231
#   step    170 | loss=1.1223 | entity_loss=0.8818 | intent_loss=0.0000 | mask_loss=0.4809 | intent_acc=1.0000 | lr=8.50e-04
# Epoch  85/100 (0.7s) | train loss=1.1223 | entity_loss=0.8818 | intent_loss=0.0000 | mask_loss=0.4809 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.9000
# Epoch  86/100 (0.7s) | train loss=0.3195 | entity_loss=0.1016 | intent_loss=0.0000 | mask_loss=0.4357 | intent_acc=1.0000
#           val   | intent_acc=0.7727 | entity_f1=0.8780
# Epoch  87/100 (0.7s) | train loss=0.8584 | entity_loss=0.5624 | intent_loss=0.0777 | mask_loss=0.4367 | intent_acc=0.9444
#           val   | intent_acc=0.7273 | entity_f1=0.7368
# Epoch  88/100 (0.7s) | train loss=0.7464 | entity_loss=0.5469 | intent_loss=0.0003 | mask_loss=0.3983 | intent_acc=1.0000
#           val   | intent_acc=0.6818 | entity_f1=0.8205
# Epoch  89/100 (0.7s) | train loss=1.5241 | entity_loss=0.7464 | intent_loss=0.5447 | mask_loss=0.4659 | intent_acc=0.9688
#           val   | intent_acc=0.6818 | entity_f1=0.7692
#   step    180 | loss=1.4097 | entity_loss=0.8842 | intent_loss=0.2896 | mask_loss=0.4718 | intent_acc=0.9688 | lr=9.00e-04
# Epoch  90/100 (0.7s) | train loss=1.4097 | entity_loss=0.8842 | intent_loss=0.2896 | mask_loss=0.4718 | intent_acc=0.9688
#           val   | intent_acc=0.6818 | entity_f1=0.7692
# Epoch  91/100 (0.7s) | train loss=2.8563 | entity_loss=0.7179 | intent_loss=1.8973 | mask_loss=0.4821 | intent_acc=0.9132
#           val   | intent_acc=0.7727 | entity_f1=0.6316
# Epoch  92/100 (0.7s) | train loss=1.9833 | entity_loss=0.5269 | intent_loss=1.2207 | mask_loss=0.4714 | intent_acc=0.9444
#           val   | intent_acc=0.7727 | entity_f1=0.8421
# Epoch  93/100 (0.7s) | train loss=0.7931 | entity_loss=0.5652 | intent_loss=0.0002 | mask_loss=0.4554 | intent_acc=1.0000
#           val   | intent_acc=0.8182 | entity_f1=0.7568
# Epoch  94/100 (0.7s) | train loss=0.5831 | entity_loss=0.3669 | intent_loss=0.0001 | mask_loss=0.4322 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.7222
#   step    190 | loss=0.7998 | entity_loss=0.5658 | intent_loss=0.0008 | mask_loss=0.4664 | intent_acc=1.0000 | lr=9.50e-04
# Epoch  95/100 (0.7s) | train loss=0.7998 | entity_loss=0.5658 | intent_loss=0.0008 | mask_loss=0.4664 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.7027
# Epoch  96/100 (0.7s) | train loss=1.2523 | entity_loss=0.8403 | intent_loss=0.1802 | mask_loss=0.4636 | intent_acc=0.9375
#           val   | intent_acc=0.9091 | entity_f1=0.7368
# Epoch  97/100 (0.7s) | train loss=0.3284 | entity_loss=0.1080 | intent_loss=0.0076 | mask_loss=0.4256 | intent_acc=1.0000
#           val   | intent_acc=0.9091 | entity_f1=0.7179
# Epoch  98/100 (0.7s) | train loss=0.8441 | entity_loss=0.6008 | intent_loss=0.0139 | mask_loss=0.4588 | intent_acc=1.0000
#           val   | intent_acc=0.8636 | entity_f1=0.7317
# Epoch  99/100 (0.7s) | train loss=0.6954 | entity_loss=0.4616 | intent_loss=0.0000 | mask_loss=0.4675 | intent_acc=1.0000
#           val   | intent_acc=0.7273 | entity_f1=0.7179
#   step    200 | loss=0.6064 | entity_loss=0.0641 | intent_loss=0.3104 | mask_loss=0.4638 | intent_acc=0.9444 | lr=1.00e-03
# Epoch 100/100 (0.7s) | train loss=0.6064 | entity_loss=0.0641 | intent_loss=0.3104 | mask_loss=0.4638 | intent_acc=0.9444
#           val   | intent_acc=0.7727 | entity_f1=0.7368
# Training complete.

# %%
# !cd /root/myhomedir/bucket/DIET_torch && python3 eval/run_eval.py \
  --checkpoint checkpoints/best.pt \
  --data data/nlu_test.yml \
  --output-dir eval/results \
  --prefix test \
  --device cuda
# Out:
# Loading Qwen tokeniser from Qwen/Qwen2.5-0.5B-Instruct …
# Loading Qwen model from Qwen/Qwen2.5-0.5B-Instruct …
# 2026-04-07 12:03:23.155788: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775563403.173599     415 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775563403.179301     415 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775563403.197234     415 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775563403.197266     415 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775563403.197270     415 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775563403.197274     415 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-07 12:03:23.202375: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# trainable params: 1,081,344 || all params: 495,114,112 || trainable%: 0.2184
# Loaded 22 test examples
#
# === INTENT CLASSIFICATION ===
#   micro       P=1.000  R=1.000  F1=1.000
#   macro       P=1.000  R=1.000  F1=1.000
#   weighted    P=1.000  R=1.000  F1=1.000
#
#   Per intent:
#     book_flight                P=1.000  R=1.000  F1=1.000  sup=4.0
#     check_weather              P=1.000  R=1.000  F1=1.000  sup=4.0
#     goodbye                    P=1.000  R=1.000  F1=1.000  sup=5.0
#     greet                      P=1.000  R=1.000  F1=1.000  sup=5.0
#     search_restaurant          P=1.000  R=1.000  F1=1.000  sup=4.0
#
# === ENTITY EXTRACTION ===
#   micro       P=0.889  R=0.800  F1=0.842
#   macro       P=0.900  R=0.800  F1=0.833
#   weighted    P=0.900  R=0.800  F1=0.833
#
#   Per entity:
#     city                            P=1.000  R=1.000  F1=1.000  tp=4 fp=0 fn=0
#     city:departure                  P=1.000  R=1.000  F1=1.000  tp=4 fp=0 fn=0
#     city:destination                P=0.750  R=0.750  F1=0.750  tp=3 fp=1 fn=1
#     cuisine                         P=1.000  R=0.500  F1=0.667  tp=2 fp=0 fn=2
#     location                        P=0.750  R=0.750  F1=0.750  tp=3 fp=1 fn=1
#
#   Intent errors: 0 / 22
#   Entity errors: 4 / 22
#   Wrote eval/results/test_report.json
#   Wrote eval/results/test_intent_errors.json
#   Wrote eval/results/test_entity_errors.json
